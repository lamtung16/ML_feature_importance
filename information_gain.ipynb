# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import mutual_info_regression
import matplotlib.pyplot as plt

# %%
# Create new data
np.random.seed(42)
x1 = np.random.rand(100)
x2 = np.random.rand(100)
x3 = np.random.rand(100)
x4 = np.random.rand(100)
noise = np.random.rand(100)
y = x1 + x2**2 + x3*x4

# Create a DataFrame
data = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'noise': noise, 'y': y})

# %%
# Extract features and target
X = data[['x1', 'x2', 'x3', 'x4', 'noise']]
y = data['y']

# Calculate information gain
information_gain = mutual_info_regression(X, y)

# %%
# Print the information gain for each feature
for feature, gain in zip(X.columns, information_gain):
    print(f"{feature}: {gain:.4f}")
# Out:
# x1: 0.2462
# x2: 0.4167
# x3: 0.0107
# x4: 0.0053
# noise: 0.0000

# %%
plt.figure(figsize=(8, 6))
plt.bar(data.columns[:-1], information_gain)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Information Gain")
plt.savefig("figs/information_gain.png", format='png')
plt.show()
